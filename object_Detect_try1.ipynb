# %%
import cv2
import matplotlib.pyplot as plt

# %%
config_file = '54a8e8b51beb3bd3f770b79e56927bd7.html'
frozen_model = 'ssd_testmodel.ipynb'

# %%
model = cv2.dnn_DetectionModel(frozen_model,config_file)
model.setInputSize(320,320)
model.setInputScale(1.0/127.5)
model.setInputMean(127.5,127.5,127.5)
model.setInputSwapRB(True)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# error: OpenCV(4.5.3) C:\Users\runneradmin\AppData\Local\Temp\pip-req-build-q3d_8t8e\opencv\modules\dnn\src\dnn.cpp:5461: error: (-2:Unspecified error) Cannot determine an origin framework of files: ssd_config.ipynb, 54a8e8b51beb3bd3f770b79e56927bd7.html in function 'cv::dnn::dnn4_v20210608::readNet'
#
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# <ipython-input-10-31b3c1d13967> in <module>
# ----> 1 model = cv2.dnn_DetectionModel(frozen_model,config_file)
#       2 model.setInputSize(320,320)
#       3 model.setInputScale(1.0/127.5)
#       4 model.setInputMean(127.5,127.5,127.5)
#       5 model.setInputSwapRB(True)
#
# SystemError: <class 'cv2.dnn_DetectionModel'> returned a result with an error set

# %%
classlabels = []
filename ='E:\Python_Progs_Visualizationonwards\labels.txt'
with open (filename,'rt') as fpt:
    classlabels=fpt.read().rstrip('\n').split('\n')
print(classlabels)
# Out:
# ['person', 'bicycle', 'car', 'motorbike', 'aeroplane', 'bus', 'train', 'truck', 'boat', 'traffic light', 'fire hydrant', 'stop sign', 'parking meter', 'bench', 'bird', 'cat', 'dog', 'horse', 'sheep', 'cow', 'elephant', 'bear', 'zebra', 'giraffe', 'backpack', 'umbrella', 'handbag', 'tie', 'suitcase', 'frisbee', 'skis', 'snowboard', 'sports ball', 'kite', 'baseball bat', 'baseball glove', 'skateboard', 'surfboard', 'tennis racket', 'bottle', 'wine glass', 'cup', 'fork', 'knife', 'spoon', 'bowl', 'banana', 'apple', 'sandwich', 'orange', 'broccoli', 'carrot', 'hot dog', 'pizza', 'donut', 'cake', 'chair', 'sofa', 'pottedplant', 'bed', 'diningtable', 'toilet', 'tvmonitor', 'laptop', 'mouse', 'remote', 'keyboard', 'cell phone', 'microwave', 'oven', 'toaster', 'sink', 'refrigerator', 'book', 'clock', 'vase', 'scissors', 'teddy bear', 'hair drier', 'toothbrush']

# %%
model.setInputSize(320,320)
model.setInputScale(1.0/127.5)
model.setInputMean(127.5,127.5,127.5)
model.setInputSwapRB(True)

# %%
#read an image
img = cv2.imread('E:\Python_Progs_Visualizationonwards\detect.jpeg')
plt.imshow(img)

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
ClassIndex, confidence, bbox = model.detect(img,confThreshold=0.5)
print(ClassIndex)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-2b897cf4a6cc> in <module>
# ----> 1 ClassIndex, confidence, bbox = model.detect(img,confThreshold=0.5)
#       2 print(ClassIndex)
#
# NameError: name 'model' is not defined

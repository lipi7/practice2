# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('E:\Learnbay_Assignments\investments.csv')
df.head()

# %%
#List all column names
print(df.columns)
list(df)
# Out:
# Index(['name', 'homepage_url', 'category_list', 'market', 'funding_total_usd',
#        'status', 'country_code', 'state_code', 'region', 'city',
#        'funding_rounds', 'founded_year', 'debt_financing', 'grant'],
#       dtype='object')
# ['name',
#  'homepage_url',
#  'category_list',
#  'market',
#  'funding_total_usd',
#  'status',
#  'country_code',
#  'state_code',
#  'region',
#  'city',
#  'funding_rounds',
#  'founded_year',
#  'debt_financing',
#  'grant']

# %%
#3.	Create a dataframe with numerical columns
#df.info()
#column funding total is being treated as a object tupe rather than numeric
df.select_dtypes(include = 'number')
#or
df2 = df.select_dtypes(include = 'number')
df2.head()
# Out:
#    funding_rounds  founded_year  debt_financing  grant
# 0               1        2012.0               0      0
# 1               2           NaN               0      0
# 2               1        2012.0               0      0
# 3               1        2011.0               0      0
# 4               2        2014.0               0      0

# %%
#4.	Create a dataframe with categorical columns
df2 = df.select_dtypes(include = 'object')
df2.head()
# Out:
#                  name                   homepage_url  \
# 0            #waywire         http://www.waywire.com
# 1  &TV Communications          http://enjoyandtv.com
# 2    Rock' Your Paper   http://www.rockyourpaper.org
# 3   (In)Touch Network  http://www.InTouchNetwork.com
# 4  -R- Ranch and Mine                            NaN
#
#                                        category_list       market  \
# 0         |Entertainment|Politics|Social Media|News|         News
# 1                                            |Games|        Games
# 2                             |Publishing|Education|   Publishing
# 3  |Electronics|Guides|Coffee|Restaurants|Music|i...  Electronics
# 4                      |Tourism|Entertainment|Games|      Tourism
#
#   funding_total_usd     status country_code state_code         region  \
# 0         17,50,000   acquired          USA         NY  New York City
# 1         40,00,000  operating          USA         CA    Los Angeles
# ...

# %%
#5.	Get a summary on the data and draw inferences if any
df.describe()

#inferences
# 1. missing values in the founded year  and debt financing
#2. funding received is 18 times which is rare
#3. debt financing and grant is 0 for 25% 50% 75% and only max is having the value or they received 
#grant and financing separately
# Out:
#        funding_rounds  founded_year  debt_financing         grant
# count    49438.000000  38482.000000    4.943800e+04  4.943800e+04
# mean         1.696205   2007.359129    1.888157e+06  1.628453e+05
# std          1.294213      7.579203    1.382046e+08  5.612088e+06
# min          1.000000   1902.000000    0.000000e+00  0.000000e+00
# 25%          1.000000   2006.000000    0.000000e+00  0.000000e+00
# 50%          1.000000   2010.000000    0.000000e+00  0.000000e+00
# 75%          2.000000   2012.000000    0.000000e+00  0.000000e+00
# max         18.000000   2014.000000    3.007950e+10  7.505000e+08

# %%
#4. date time
pd.to_datetime(df.founded_year,format = '%Y')
# Out:
# 0       2012-01-01
# 1              NaT
# 2       2012-01-01
# 3       2011-01-01
# 4       2014-01-01
#            ...
# 49433   2013-01-01
# 49434          NaT
# 49435   2012-01-01
# 49436          NaT
# 49437   1999-01-01
# Name: founded_year, Length: 49438, dtype: datetime64[ns]

# %%
#6.	Display duplicate rows.
#df.duplicated()# duplicate at row level if duplicate true
df.duplicated().sum() # if 0 there is no row level duplicates
# Out:
# 0

# %%
#df.head()
#duplicate names checked for name and market level column

df.duplicated(subset = ['name','category_list','market']).sum()
#there are three records duplicate at name catorgory list and market
# Out:
# 3

# %%
#records having duplicates
df[df.duplicated(subset = ['name','category_list','market'])]
# Out:
#                     name            homepage_url    category_list  \
# 4150   AYOXXA Biosystems  http://www.ayoxxa.com/  |Biotechnology|
# 24028       Lightex Ltd.                     NaN              NaN
# 36084            Roadmap                     NaN              NaN
#
#               market funding_total_usd     status country_code state_code  \
# 4150   Biotechnology       1,40,81,347  operating          DEU        NaN
# 24028            NaN          5,00,000  operating          NaN        NaN
# 36084            NaN                 -  operating          USA         NC
#
#           region       city  funding_rounds  founded_year  debt_financing  \
# 4150     Cologne       Köln               1        2010.0               0
# 24028        NaN        NaN               1           NaN               0
# 36084  Charlotte  Charlotte               1        2011.0               0
#
#        grant
# 4150       0
# 24028      0
# 36084      0

# %%
#finding records
f = (df.name == 'AYOXXA Biosystems')& (df.category_list == '|Biotechnology|') & (df.market== 'Biotechnology')
df[f]
# Out:
#                    name            homepage_url    category_list  \
# 4149  AYOXXA Biosystems       http://ayoxxa.com  |Biotechnology|
# 4150  AYOXXA Biosystems  http://www.ayoxxa.com/  |Biotechnology|
#
#              market funding_total_usd     status country_code state_code  \
# 4149  Biotechnology       1,21,45,503  operating          DEU        NaN
# 4150  Biotechnology       1,40,81,347  operating          DEU        NaN
#
#        region     city  funding_rounds  founded_year  debt_financing  grant
# 4149  Cologne  Cologne               1        2010.0               0      0
# 4150  Cologne     Köln               1        2010.0               0      0

# %%
#deleting duplicate
df.drop_duplicates()
# Out:
#                                 name                   homepage_url  \
# 0                           #waywire         http://www.waywire.com
# 1                 &TV Communications          http://enjoyandtv.com
# 2                   Rock' Your Paper   http://www.rockyourpaper.org
# 3                  (In)Touch Network  http://www.InTouchNetwork.com
# 4                 -R- Ranch and Mine                            NaN
# ...                              ...                            ...
# 49433                          Zzish           http://www.zzish.com
# 49434  ZZNode Science and Technology          http://www.zznode.com
# 49435          Zzzzapp Wireless ltd.         http://www.zzzzapp.com
# 49436                  [a]list games      http://www.alistgames.com
# 49437                          [x+1]       http://www.xplusone.com/
#
#                                            category_list               market  \
# ...

# %%
df.drop_duplicates(subset = ['name','category_list','market'],keep = False,inplace = False).shape
# Out:
# (49432, 14)

# %%
df.shape
# Out:
# (49438, 14)

# %%
#7.For each column find out the percentage of missing values
#all cell level is checked whether it is null
df.isnull().sum()
# 1st coolumn name and second is count of missing valules
df.isnull().sum()/df.shape[0] *100 #38 % of companies dont hae state code and 22 % of companies doesnt have founuded year
#shape[0] to find itrow wise
# Out:
# name                    0.002023
# homepage_url            6.976415
# category_list           8.012056
# market                  8.026215
# funding_total_usd       0.000000
# status                  2.657875
# country_code           10.665885
# state_code             38.992273
# region                 10.665885
# city                   12.371051
# funding_rounds          0.000000
# founded_year           22.161091
# debt_financing          0.000000
# grant                   0.000000
# category_list_count     0.000000
# dtype: float64

# %%
df.isna().sum()/df.shape[0] *100
# Out:
# name                  0.002023
# homepage_url          6.976415
# category_list         8.012056
# market                8.026215
# funding_total_usd     0.000000
# status                2.657875
# country_code         10.665885
# state_code           38.992273
# region               10.665885
# city                 12.371051
# funding_rounds        0.000000
# founded_year         22.161091
# debt_financing        0.000000
# grant                 0.000000
# dtype: float64

# %%
df[df.name.isna()]
# Out:
#       name           homepage_url category_list    market funding_total_usd  \
# 28221  NaN  http://tellitin10.com    |Startups|  Startups            25,000
#
#        status country_code state_code region city  funding_rounds  \
# 28221  closed          NaN        NaN    NaN  NaN               1
#
#        founded_year  debt_financing  grant
# 28221        2011.0               0      0

# %%
#to create in a proper frame
cnt_m = df.isnull().sum()
per_m = df.isnull().sum()/df.shape[0] *100 #percentage of missing values
pd.concat([cnt_m,per_m],axis = 1,keys = ['count_m','percentage_M']).sort_values('percentage_M',ascending = False)

#approaching how to handle missing values: there are diff which to choose based on % of how much % missing value is there.
# Out:
#                    count_m  percentage_M
# state_code           19277     38.992273
# founded_year         10956     22.161091
# city                  6116     12.371051
# country_code          5273     10.665885
# region                5273     10.665885
# market                3968      8.026215
# category_list         3961      8.012056
# homepage_url          3449      6.976415
# status                1314      2.657875
# name                     1      0.002023
# funding_total_usd        0      0.000000
# funding_rounds           0      0.000000
# debt_financing           0      0.000000
# grant                    0      0.000000

# %%
#8.	Find count of ‘name’ in each ‘country_code’.

#get of companyes name based on country code

df.groupby('country_code')['name'].count()
# Out:
# country_code
# ALB        1
# ARE       66
# ARG      149
# ARM        2
# AUS      314
#        ...
# USA    28793
# UZB        1
# VNM       21
# ZAF       52
# ZWE        1
# Name: name, Length: 115, dtype: int64

# %%
#9.What is the percentage of the companies which have status ‘acquired’ or ‘operating’?
df[df.status.isin(['operating','acquired'])]
# Out:
#                                 name                   homepage_url  \
# 0                           #waywire         http://www.waywire.com
# 1                 &TV Communications          http://enjoyandtv.com
# 2                   Rock' Your Paper   http://www.rockyourpaper.org
# 3                  (In)Touch Network  http://www.InTouchNetwork.com
# 4                 -R- Ranch and Mine                            NaN
# ...                              ...                            ...
# 49433                          Zzish           http://www.zzish.com
# 49434  ZZNode Science and Technology          http://www.zznode.com
# 49435          Zzzzapp Wireless ltd.         http://www.zzzzapp.com
# 49436                  [a]list games      http://www.alistgames.com
# 49437                          [x+1]       http://www.xplusone.com/
#
#                                            category_list               market  \
# ...

# %%
#subsetting and finding
df[df.status.isin(['operating','acquired'])].shape
# Out:
# (45521, 14)

# %%
#in percenatge
df[df.status.isin(['operating','acquired'])].shape[0]/len(df)*100
# Out:
# 92.07694486022898

# %%
#11.Filter records having missing values in column ‘year_founded’.
df[df.founded_year.isna()]
# Out:
#                                 name                  homepage_url  \
# 1                 &TV Communications         http://enjoyandtv.com
# 6                      .Fox Networks         http://www.dotfox.com
# 9                 01Games Technology        http://www.01games.hk/
# 11                           1-4 All                           NaN
# 19                 1000jobboersen.de  http://www.1000jobboersen.de
# ...                              ...                           ...
# 49412               Zygo Corporation           http://www.zygo.com
# 49422                     Zymr, Inc.           http://www.zymr.com
# 49431                          Zyrra          http://www.zyrra.com
# 49434  ZZNode Science and Technology         http://www.zznode.com
# 49436                  [a]list games     http://www.alistgames.com
#
#                                            category_list               market  \
# 1                                                |Games|                Games
# ...

# %%
df[df.founded_year.isna()].shape[0]
# Out:
# 10956

# %%
#12.Create a column ‘category_list_count’ having count of category lists.
# count of substrings from a given string 
#count of subwords

# %%
df.head()
# Out:
#                  name                   homepage_url  \
# 0            #waywire         http://www.waywire.com
# 1  &TV Communications          http://enjoyandtv.com
# 2    Rock' Your Paper   http://www.rockyourpaper.org
# 3   (In)Touch Network  http://www.InTouchNetwork.com
# 4  -R- Ranch and Mine                            NaN
#
#                                        category_list       market  \
# 0         |Entertainment|Politics|Social Media|News|         News
# 1                                            |Games|        Games
# 2                             |Publishing|Education|   Publishing
# 3  |Electronics|Guides|Coffee|Restaurants|Music|i...  Electronics
# 4                      |Tourism|Entertainment|Games|      Tourism
#
#   funding_total_usd     status country_code state_code         region  \
# 0         17,50,000   acquired          USA         NY  New York City
# 1         40,00,000  operating          USA         CA    Los Angeles
# ...

# %%
len('|Entertainment|Politics|Social Media|News|'.split('|'))
# Out:
# 6

# %%
df.category_list.apply(lambda x: len(str(x).split('|'))-2)
# Out:
# 0         4
# 1         1
# 2         2
# 3        10
# 4         3
#          ..
# 49433     6
# 49434     1
# 49435     4
# 49436     1
# 49437     1
# Name: category_list, Length: 49438, dtype: int64

# %%
df['category_list_count'] = df.category_list.apply(lambda x: len(str(x).split('|'))-2)
df.loc[:,['category_list','category_list_count']].head()
# Out:
#                                        category_list  category_list_count
# 0         |Entertainment|Politics|Social Media|News|                    4
# 1                                            |Games|                    1
# 2                             |Publishing|Education|                    2
# 3  |Electronics|Guides|Coffee|Restaurants|Music|i...                   10
# 4                      |Tourism|Entertainment|Games|                    3

# %%
#13.Find average funding_total_usd for each country_code.
df.groupby('country_code')['funding_total_usd'].mean() # funding total usd is object type
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-39-5cd0cd92bfef> in <module>
#       1 #13.Find average funding_total_usd for each country_code.
# ----> 2 df.groupby('country_code')['funding_total_usd'].shape[0].mean() # funding total usd is object type
#
# E:\Anaconda\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     701             return self[attr]
#     702
# --> 703         raise AttributeError(
#     704             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     705         )
#
# AttributeError: 'SeriesGroupBy' object has no attribute 'shape'

# %%
df.funding_total_usd.tolist()
# ',' , '-'
#','-> ''
#'-'-> '0', 'np.null',np.nan
# Out:
# ['17,50,000',
#  '40,00,000',
#  '40,000',
#  '15,00,000',
#  '60,000',
#  '70,00,000',
#  '49,12,393',
#  '20,00,000',
#  '-',
#  '41,250',
#  '40,000',
#  '-',
#  '-',
#  '17,50,000',
#  '-',
#  '44,00,000',
#  '20,50,000',
#  '40,000',
#  '5,00,000',
#  '-',
#  '25,35,000',
#  '49,62,651',
#  '40,59,079',
#  '1,00,00,000',
#  '30,00,000',
#  '45,00,000',
#  '4,20,000',
#  '12,50,000',
#  '3,50,00,000',
#  '-',
#  '50,000',
#  '16,00,000',
#  '1,00,000',
#  '-',
#  '30,00,000',
#  '77,500',
#  '-',
#  '2,00,00,000',
#  '18,00,000',
#  '-',
#  '-',
#  '-',
#  '-',
#  '2,70,000',
#  '7,94,000',
#  '6,50,267',
#  '-',
#  '3,78,812',
#  '1,30,636',
#  '6,19,494',
#  '-',
#  '6,64,50,000',
#  '-',
#  '7,00,000',
#  '55,00,000',
#  '5,00,000',
#  '62,04,822',
#  '34,00,000',
#  '2,00,000',
#  '1,99,957',
#  '50,000',
#  '-',
#  '1,40,00,000',
#  '8,44,40,319',
#  '25,00,000',
#  '94,78,511',
#  '-',
#  '20,00,00,000',
#  '40,000',
#  '-',
#  '-',
#  '-',
#  '40,000',
#  '43,811',
# ...

# %%
float('45000')
float('0')
float(np.nan) #this is float type

# %%
df.funding_total_usd.apply(lambda x: x.replace(',','').replace('-','0')).tolist()

# %%
df.funding_total_usd.apply(lambda x: x.replace(',','').replace('-','0')).astype(float)

# %%
#df.funding_total_usd = df.funding_total_usd.apply(lambda x: x.replace(',','').replace('-','0')).astype(float)

# %%
df.groupby('country_code')['funding_total_usd'].mean()
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# <ipython-input-41-686a7c7d4995> in <module>
# ----> 1 df.groupby('country_code')['funding_total_usd'].mean()
#
# E:\Anaconda\lib\site-packages\pandas\core\groupby\groupby.py in mean(self, numeric_only)
#    1391         Name: B, dtype: float64
#    1392         """
# -> 1393         return self._cython_agg_general(
#    1394             "mean",
#    1395             alt=lambda x, axis: Series(x).mean(numeric_only=numeric_only),
#
# E:\Anaconda\lib\site-packages\pandas\core\groupby\groupby.py in _cython_agg_general(self, how, alt, numeric_only, min_count)
#    1049
#    1050         if len(output) == 0:
# -> 1051             raise DataError("No numeric types to aggregate")
#    1052
#    1053         return self._wrap_aggregated_output(output, index=self.grouper.result_index)
#
# DataError: No numeric types to aggregate

# %%
#14.Find total funding_total_usd for each country_code.
df.groupby('country_code')['funding_total_usd'].sum()
# Out:
# country_code
# ALB                                                    -
# ARE    3,00,00,0006,00,00,0001,00,0001,50,00016,00,00...
# ARG    49,12,3931,31,5688,50,0003,50,00012,25,00025,0...
# ARM                                  2,65,17,5002,95,476
# AUS    1,00,0002,70,0003,83,0003,00,000-1,05,65130,10...
#                              ...
# USA    17,50,00040,00,00060,00070,00,000---17,50,000-...
# UZB                                               90,000
# VNM    -9,00,00,000----1,00,000-35,00,0001,50,00,0001...
# ZAF    -3,35,00,000-20,0002,50,00,000-28,50,00037,00,...
# ZWE                                          1,00,00,000
# Name: funding_total_usd, Length: 115, dtype: object

# %%
##

# %%
#15.Find average funding_total_usd in each country_code and region.

# %%
df.groupby(['country_code','region'])['funding_total_usd'].mean()

# %%
#16.How many companies have got just 1 round of funding?
print(df[df.funding_rounds == 1]['name'].unique())
print(len(df[df.funding_rounds == 1]['name'].unique()))  #nan is couted #excluding duplicates
print(df[df.funding_rounds == 1]['name'].nunique()) # nan is not counted excluding duplicates and nan
print(df[df.funding_rounds == 1]['name'].shape[0]) #including duplicates names
print(df[df.funding_rounds == 1]['name'].count()) #excluding nans
# Out:
# ['#waywire' "Rock' Your Paper" '(In)Touch Network' ... 'Zzish'
#  'ZZNode Science and Technology' '[a]list games']
# 32006
# 32005
# 32039
# 32038

# %%
df[df.funding_rounds == 1]['name'].shape[0] #including duplicates names

# %%
#17.	Perform mapping on status column; acquired -> A, operating -> O and closed -> C.

df.status.unique()

# %%
df.status.apply(lambda x: 'A' if x == 'acquired' else x =='O' if x == 'operating' else 'C' if x == 'closed' else 'missing')

# %%
#18.	How many companies have ‘debt_financing’ above zero?
#19.	Create a column ‘homepage’ to store company name from ‘homepage_url’:
#For example: If url is http://www.waywire.com, name is waywire.
import re
df.homepage_url.apply(lambda x: re.sub(' http://www.|.com','',str(x))).head()

# %%
#20.	Find the count of companies in each of the markets.
df.groupby('market')['name'].count()
# Out:
# market
# 3D               25
# 3D Printing       9
# 3D Technology     8
# Accounting       18
# Ad Targeting     13
#                  ..
# iOS              48
# iPad             29
# iPhone           69
# iPod Touch        3
# mHealth           8
# Name: name, Length: 753, dtype: int64

# %%
#21.Find the count of companies in each of the markets and store the new column ‘cnt_name’ in the original dataframe.
df['cnt_company']= df.groupby('market')['name'].transform('count')
df
# Out:
#                                 name                   homepage_url  \
# 0                           #waywire         http://www.waywire.com
# 1                 &TV Communications          http://enjoyandtv.com
# 2                   Rock' Your Paper   http://www.rockyourpaper.org
# 3                  (In)Touch Network  http://www.InTouchNetwork.com
# 4                 -R- Ranch and Mine                            NaN
# ...                              ...                            ...
# 49433                          Zzish           http://www.zzish.com
# 49434  ZZNode Science and Technology          http://www.zznode.com
# 49435          Zzzzapp Wireless ltd.         http://www.zzzzapp.com
# 49436                  [a]list games      http://www.alistgames.com
# 49437                          [x+1]       http://www.xplusone.com/
#
#                                            category_list               market  \
# ...

# %%
df.groupby('market')['name'].count()

# %%
#23.	Fill missing values in column ‘city’ with ‘other_city’
df.city.tolist()

# %%
df.city.fillna('other_city').tolist()

# %%
#25.Normalize ‘‘funding_total_usd’ at country level
df.groupby('country_code')['funding_total_usd'].transform(lambda x: x/np.max(x))

# %%
df.country_code.tolist() #it has nan so the groupby to handle nan
# replace nan with other country

# %%
df.country_code.fillna('other_country',inplace = True)

# %%
#24.For each row in column ‘funding_total_usd’, calculate actual – average value for each group ‘city’
df.groupby('funding_total_usd')['city'].count()

# %%
#26.	What is the average ‘funding_total_usd’ for each city?
df.groupby('city')['funding_total_usd'].mean()

# %%
#28.	What is maximum ‘funding_total_usd’ for each market status?
df.groupby('market')['funding_total_usd'].max()

# %%
#29.	How many years has it been since each company was founded?
df['company_age'] = 2021-df.founded_year #use time function to get current year
df.head()

# %%
from datetime import datetime
datetime.today()

df['company_age'] = datetime.today().year()-df.founded_year
df.head()

# %%
datetime.today()

# %%
#32.	Display proportion of companies status
df.status.value_counts()

# %%
df.status.value_counts()/df.shape[0] *100 # it doesn't display count of nans

# %%
#33.	How many US states are available
df[df.country_code == 'USA']['state_code'].nunique()

# %%
#34.	create column ‘cmt_address’ by joining country code, state code, region and city.
df['cm_address']= df.country_code + '-' + df.state_code + '-' + df.region + '-' + df.city
# if nana whole sum will be nan of the complete address

# %%
#35.	select columns with underscore in their names
df.columns

# %%
df.filter(regex='_')

# %%
df.head()

# %%
df.country_code + "-" + np.where(df.state_code.isna(),'missing',df.state_code).tolist()

# %%
#27.	Plot histogram/distribution of ‘funding_total_usd’ and provide insights if any.

plt.hist(df.funding_total_usd)
plt.xlabel('funding_total_usd')
plt.ylabel('count')
plt.show()

#skew data

# %%
plt.hist(np.log1p(df.funding_total_usd))
plt.xlabel('funding_total_usd')
plt.ylabel('count')
plt.show()

# %%
#30.	Visualize ‘grant’ distribution
plt.hist(df.grant)
plt.xlabel('grant')
plt.ylabel('count')
plt.show()

# %%
plt.hist(np.log1p(df.grant))
plt.xlabel('grant')
plt.ylabel('count')
plt.show()

# %%
#31.	Visualize ‘debt_financing’ distribution
plt.hist(df.debt_financing)
plt.xlabel('debt financing')
plt.ylabel('count')
plt.show()

# %%
plt.hist(np.log1p(df.debt_financing))
plt.xlabel('debt financing')
plt.ylabel('count')
plt.show()

# %%
a.append(pd.Series({'c':9,'d':4},name = ['x']))

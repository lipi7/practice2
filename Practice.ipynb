# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('E:\Learnbay_Assignments\practice.csv')
df.head()
# Out:
#    MSSubClass MSZoning  LotArea LotShape LotConfig LandSlope  OverallQual  \
# 0          60       RL     8450      Reg    Inside       Gtl            7
# 1          20       RL     9600      Reg       FR2       Gtl            6
# 2          60       RL    11250      IR1    Inside       Gtl            7
# 3          70       RL     9550      IR1    Corner       Gtl            7
# 4          60       RL    14260      IR1       FR2       Gtl            8
#
#    YearBuilt  MasVnrArea ExterQual BsmtExposure
# 0       2003         196        Gd           No
# 1       1976           0        TA           Gd
# 2       2001         162        Gd           Mn
# 3       1915           0        TA           No
# 4       2000         350        Gd           Av

# %%
cols = df.columns
print(cols)
# Out:
# Index(['MSSubClass', 'MSZoning', 'LotArea', 'LotShape', 'LotConfig',
#        'LandSlope', 'OverallQual', 'YearBuilt', 'MasVnrArea', 'ExterQual',
#        'BsmtExposure'],
#       dtype='object')

# %%
#3.	display size of the data-frame
sz = df.size
print(sz)
# Out:
# 330

# %%
#4.	rename column MSSubClass -> SubClass, MSZoning -> Zones
df['MSSubClass'].replace('SubClass')
# Out:
# 0      60
# 1      20
# 2      60
# 3      70
# 4      60
# 5      50
# 6      20
# 7      60
# 8      50
# 9     190
# 10     20
# 11     60
# 12     20
# 13     20
# 14     20
# 15     45
# 16     20
# 17     90
# 18     20
# 19     20
# 20     60
# 21     45
# 22     20
# 23    120
# 24     20
# 25     20
# 26     20
# 27     20
# 28     20
# 29     30
# Name: MSSubClass, dtype: int64

# %%
#2.	create numerical and categorical columns list
df.select_dtypes(include = 'number')
# Out:
#     MSSubClass  LotArea  OverallQual  YearBuilt  MasVnrArea
# 0           60     8450            7       2003         196
# 1           20     9600            6       1976           0
# 2           60    11250            7       2001         162
# 3           70     9550            7       1915           0
# 4           60    14260            8       2000         350
# 5           50    14115            5       1993           0
# 6           20    10084            8       2004         186
# 7           60    10382            7       1973         240
# 8           50     6120            7       1931           0
# 9          190     7420            5       1939           0
# 10          20    11200            5       1965           0
# 11          60    11924            9       2005         286
# 12          20    12968            5       1962           0
# 13          20    10652            7       2006         306
# 14          20    10920            6       1960         212
# ...

# %%
df.select_dtypes(include = 'object')
# Out:
#    MSZoning LotShape LotConfig LandSlope ExterQual BsmtExposure
# 0        RL      Reg    Inside       Gtl        Gd           No
# 1        RL      Reg       FR2       Gtl        TA           Gd
# 2        RL      IR1    Inside       Gtl        Gd           Mn
# 3        RL      IR1    Corner       Gtl        TA           No
# 4        RL      IR1       FR2       Gtl        Gd           Av
# 5        RL      IR1    Inside       Gtl        TA           No
# 6        RL      Reg    Inside       Gtl        Gd           Av
# 7        RL      IR1    Corner       Gtl        TA           Mn
# 8        RM      Reg    Inside       Gtl        TA           No
# 9        RL      Reg    Corner       Gtl        TA           No
# 10       RL      Reg    Inside       Gtl        TA           No
# 11       RL      IR1    Inside       Gtl        Ex           No
# 12       RL      IR2    Inside       Gtl        TA           No
# 13       RL      IR1    Inside       Gtl        Gd           Av
# ...

# %%
df.head()
# Out:
#    MSSubClass MSZoning  LotArea LotShape LotConfig LandSlope  OverallQual  \
# 0          60       RL     8450      Reg    Inside       Gtl            7
# 1          20       RL     9600      Reg       FR2       Gtl            6
# 2          60       RL    11250      IR1    Inside       Gtl            7
# 3          70       RL     9550      IR1    Corner       Gtl            7
# 4          60       RL    14260      IR1       FR2       Gtl            8
#
#    YearBuilt  MasVnrArea ExterQual BsmtExposure
# 0       2003         196        Gd           No
# 1       1976           0        TA           Gd
# 2       2001         162        Gd           Mn
# 3       1915           0        TA           No
# 4       2000         350        Gd           Av

# %%
#4.	rename column MSSubClass -> SubClass, MSZoning -> Zones
df.rename(columns={'MSSubClass' : 'SubClass','MSZoning':'Zones'})
# Out:
#     SubClass Zones  LotArea LotShape LotConfig LandSlope  OverallQual  \
# 0         60    RL     8450      Reg    Inside       Gtl            7
# 1         20    RL     9600      Reg       FR2       Gtl            6
# 2         60    RL    11250      IR1    Inside       Gtl            7
# 3         70    RL     9550      IR1    Corner       Gtl            7
# 4         60    RL    14260      IR1       FR2       Gtl            8
# 5         50    RL    14115      IR1    Inside       Gtl            5
# 6         20    RL    10084      Reg    Inside       Gtl            8
# 7         60    RL    10382      IR1    Corner       Gtl            7
# 8         50    RM     6120      Reg    Inside       Gtl            7
# 9        190    RL     7420      Reg    Corner       Gtl            5
# 10        20    RL    11200      Reg    Inside       Gtl            5
# 11        60    RL    11924      IR1    Inside       Gtl            9
# ...

# %%
#5.	display distinct values for Zoning, LotShape, LotConfig
pd.unique(df[['MSZoning', 'LotShape','LotConfig']].values.ravel('K'))
#The argument 'K' tells the method to flatten the array in the order the elements are stored in the memory (pandas typically stores underlying arrays in Fortran-contiguous order; columns before rows). 
#This can be significantly faster than using the method's default 'C' order.
#or
#np.unique(df[['MSZoning', 'LotShape','LotConfig']].values)
# Out:
# array(['RL', 'RM', 'Reg', 'IR1', 'IR2', 'Inside', 'FR2', 'Corner',
#        'CulDSac'], dtype=object)

# %%
#6.	display count of distinct values for Zoning, LotShape, LotConfig

#len(set(zip(df['col_a'],df['col_b'])))
#Out[106]: 6

#df.groupby(['col_a', 'col_b']).ngroups
#Out[101]: 6

df.groupby(['MSZoning','LotShape','LotConfig']).ngroups

#len(set(zip(df['MSZoning'],df['LotShape'],df['LotConfig'])))

#pd.unique(df[['MSZoning','LotShape','LotConfig']].count())
#print(len(df[df.MSZoning == 1]['name'].unique()))
# Out:
# 11

# %%
#7.max, min of column YearBuilt

maxYrBuilt = df['YearBuilt'].max()
print(maxYrBuilt)
minYrBuilt = df['YearBuilt'].min()
print(minYrBuilt)

# %%
#8.	create a new column “year _diff’. This will be holding difference of current year and YearBuilt
import datetime as datetime
df['year_diff'] = 2021 - df.YearBuilt
df.loc[:,['YearBuilt','year_diff']].head()
#df['year_diff']
# Out:
#    YearBuilt  year_diff
# 0       2003         18
# 1       1976         45
# 2       2001         20
# 3       1915        106
# 4       2000         21

# %%
#9.	display distinct MSZoning for each OverallQual
df.groupby('OverallQual')['MSZoning'].nunique()
# Out:
# OverallQual
# 4    2
# 5    2
# 6    1
# 7    2
# 8    1
# 9    1
# Name: MSZoning, dtype: int64

# %%
#10.	What is the maximum LotArea where  BsmtExposure = Mn?
df.groupby('BsmtExposure')['LotArea'].max()
# Out:
# BsmtExposure
# Av    14260
# Gd    16321
# Mn    11250
# No    14230
# Name: LotArea, dtype: int64

# %%
#11.	Sort dataframe based on following columns and orders: MSSubClass; ascending, YearBuilt:descending;
df.sort_values(by=['MSSubClass','YearBuilt'],ascending=(True,False))
#df[df[MSSubClass,YearBuilt]].sort_values('MSSubClass',ascending = True,'YearBuilt',ascending = False)
# Out:
#     MSSubClass MSZoning  LotArea LotShape LotConfig LandSlope  OverallQual  \
# 25          20       RL    14230      Reg    Corner       Gtl            8
# 27          20       RL    11478      Reg    Inside       Gtl            8
# 13          20       RL    10652      IR1    Inside       Gtl            7
# 6           20       RL    10084      Reg    Inside       Gtl            8
# 18          20       RL    13695      Reg    Inside       Gtl            5
# 22          20       RL     9742      Reg    Inside       Gtl            8
# 1           20       RL     9600      Reg       FR2       Gtl            6
# 16          20       RL    11241      IR1   CulDSac       Gtl            6
# 24          20       RL     8246      IR1    Inside       Gtl            5
# 10          20       RL    11200      Reg    Inside       Gtl            5
# 12          20       RL    12968      IR2    Inside       Gtl            5
# ...

# %%
#12.	What is average OverallQual
df.OverallQual.mean()
# Out:
# 6.3

# %%
#13.	convert column ‘YearBuilt’ into date type
pd.to_datetime(df.YearBuilt,format = '%Y')
# Out:
# 0    2003-01-01
# 1    1976-01-01
# 2    2001-01-01
# 3    1915-01-01
# 4    2000-01-01
# 5    1993-01-01
# 6    2004-01-01
# 7    1973-01-01
# 8    1931-01-01
# 9    1939-01-01
# 10   1965-01-01
# 11   2005-01-01
# 12   1962-01-01
# 13   2006-01-01
# 14   1960-01-01
# 15   1929-01-01
# 16   1970-01-01
# 17   1967-01-01
# 18   2004-01-01
# 19   1958-01-01
# 20   2005-01-01
# 21   1930-01-01
# 22   2002-01-01
# 23   1976-01-01
# 24   1968-01-01
# 25   2007-01-01
# 26   1951-01-01
# 27   2007-01-01
# 28   1957-01-01
# 29   1927-01-01
# Name: YearBuilt, dtype: datetime64[ns]

# %%
#14.	Group by YearBuilt and find maximum OverallQal
df.groupby('YearBuilt')['OverallQual'].max()
# Out:
# YearBuilt
# 1915    7
# 1927    4
# 1929    7
# 1930    7
# 1931    7
# 1939    5
# 1951    5
# 1957    5
# 1958    5
# 1960    6
# 1962    5
# 1965    5
# 1967    4
# 1968    5
# 1970    6
# 1973    7
# 1976    6
# 1993    5
# 2000    8
# 2001    7
# 2002    8
# 2003    7
# 2004    8
# 2005    9
# 2006    7
# 2007    8
# Name: OverallQual, dtype: int64

# %%
#15.	Load the practice.csv again with MSSubClass as new index
df = pd.read_csv('E:\Learnbay_Assignments\practice.csv')
df.head()
# Out:
#    MSSubClass MSZoning  LotArea LotShape LotConfig LandSlope  OverallQual  \
# 0          60       RL     8450      Reg    Inside       Gtl            7
# 1          20       RL     9600      Reg       FR2       Gtl            6
# 2          60       RL    11250      IR1    Inside       Gtl            7
# 3          70       RL     9550      IR1    Corner       Gtl            7
# 4          60       RL    14260      IR1       FR2       Gtl            8
#
#    YearBuilt  MasVnrArea ExterQual BsmtExposure
# 0       2003         196        Gd           No
# 1       1976           0        TA           Gd
# 2       2001         162        Gd           Mn
# 3       1915           0        TA           No
# 4       2000         350        Gd           Av

# %%
#16.	Convert LotArea as numpy array
#df = pd.DataFrame(data, columns = ['Name','Age','Birth Year','Graduation Year']
#df.to_numpy(df.LotArea)
#number_column = a_dataframe.loc[:,'Numbers']
numLotArea = df.loc[:'LotArea']
num = numLotArea.values
print(num)
# Out:
# [[60 'RL' 8450 'Reg' 'Inside' 'Gtl' 7 2003 196 'Gd' 'No' 18]
#  [20 'RL' 9600 'Reg' 'FR2' 'Gtl' 6 1976 0 'TA' 'Gd' 45]
#  [60 'RL' 11250 'IR1' 'Inside' 'Gtl' 7 2001 162 'Gd' 'Mn' 20]
#  [70 'RL' 9550 'IR1' 'Corner' 'Gtl' 7 1915 0 'TA' 'No' 106]
#  [60 'RL' 14260 'IR1' 'FR2' 'Gtl' 8 2000 350 'Gd' 'Av' 21]
#  [50 'RL' 14115 'IR1' 'Inside' 'Gtl' 5 1993 0 'TA' 'No' 28]
#  [20 'RL' 10084 'Reg' 'Inside' 'Gtl' 8 2004 186 'Gd' 'Av' 17]
#  [60 'RL' 10382 'IR1' 'Corner' 'Gtl' 7 1973 240 'TA' 'Mn' 48]
#  [50 'RM' 6120 'Reg' 'Inside' 'Gtl' 7 1931 0 'TA' 'No' 90]
#  [190 'RL' 7420 'Reg' 'Corner' 'Gtl' 5 1939 0 'TA' 'No' 82]
#  [20 'RL' 11200 'Reg' 'Inside' 'Gtl' 5 1965 0 'TA' 'No' 56]
#  [60 'RL' 11924 'IR1' 'Inside' 'Gtl' 9 2005 286 'Ex' 'No' 16]
#  [20 'RL' 12968 'IR2' 'Inside' 'Gtl' 5 1962 0 'TA' 'No' 59]
#  [20 'RL' 10652 'IR1' 'Inside' 'Gtl' 7 2006 306 'Gd' 'Av' 15]
#  [20 'RL' 10920 'IR1' 'Corner' 'Gtl' 6 1960 212 'TA' 'No' 61]
#  [45 'RM' 6120 'Reg' 'Corner' 'Gtl' 7 1929 0 'TA' 'No' 92]
# ...

# %%
#17.	In column MasVnrArea replace 0 with -1
df["MasVnrArea"].replace({0:-1}, inplace=True)
print(df)
# Out:
#     MSSubClass MSZoning  LotArea LotShape LotConfig LandSlope  OverallQual  \
# 0           60       RL     8450      Reg    Inside       Gtl            7
# 1           20       RL     9600      Reg       FR2       Gtl            6
# 2           60       RL    11250      IR1    Inside       Gtl            7
# 3           70       RL     9550      IR1    Corner       Gtl            7
# 4           60       RL    14260      IR1       FR2       Gtl            8
# 5           50       RL    14115      IR1    Inside       Gtl            5
# 6           20       RL    10084      Reg    Inside       Gtl            8
# 7           60       RL    10382      IR1    Corner       Gtl            7
# 8           50       RM     6120      Reg    Inside       Gtl            7
# 9          190       RL     7420      Reg    Corner       Gtl            5
# 10          20       RL    11200      Reg    Inside       Gtl            5
# ...

# %%
#18.	Check if there is/are any Null values (NaN) in the data given
df.isna().shape[0]
# Out:
# 30

# %%
#19.	Display percentage of missing values in each column if any
#df.isna().shape[1]/len(df) *100

percent_missing = df.isnull().sum() * 100 / len(df)
missing_value_df = pd.DataFrame({'column_name': df.columns,
                                 'percent_missing': percent_missing})
#missing_value_df.sort_values('percent_missing', inplace=True)
print(missing_value_df)
# Out:
#                column_name  percent_missing
# MSSubClass      MSSubClass         0.000000
# MSZoning          MSZoning         0.000000
# LotArea            LotArea         0.000000
# LotShape          LotShape         0.000000
# LotConfig        LotConfig         0.000000
# LandSlope        LandSlope         0.000000
# OverallQual    OverallQual         0.000000
# YearBuilt        YearBuilt         0.000000
# MasVnrArea      MasVnrArea         0.000000
# ExterQual        ExterQual         0.000000
# BsmtExposure  BsmtExposure         3.333333
# year_diff        year_diff         0.000000

# %%
#20.	Select records where LotConfig is Inside
df[df.LotConfig == 'Inside']
# Out:
#     MSSubClass MSZoning  LotArea LotShape LotConfig LandSlope  OverallQual  \
# 0           60       RL     8450      Reg    Inside       Gtl            7
# 2           60       RL    11250      IR1    Inside       Gtl            7
# 5           50       RL    14115      IR1    Inside       Gtl            5
# 6           20       RL    10084      Reg    Inside       Gtl            8
# 8           50       RM     6120      Reg    Inside       Gtl            7
# 10          20       RL    11200      Reg    Inside       Gtl            5
# 11          60       RL    11924      IR1    Inside       Gtl            9
# 12          20       RL    12968      IR2    Inside       Gtl            5
# 13          20       RL    10652      IR1    Inside       Gtl            7
# 17          90       RL    10791      Reg    Inside       Gtl            4
# 18          20       RL    13695      Reg    Inside       Gtl            5
# ...

# %%
#21.	Make a new dataframe with only numeric columns
df2 = df.select_dtypes(include = 'number')
df2.head()
# Out:
#    MSSubClass  LotArea  OverallQual  YearBuilt  MasVnrArea  year_diff
# 0          60     8450            7       2003         196         18
# 1          20     9600            6       1976          -1         45
# 2          60    11250            7       2001         162         20
# 3          70     9550            7       1915          -1        106
# 4          60    14260            8       2000         350         21

# %%
#22.	Make a new dataframe with only factorial/string columns
df2 = df.select_dtypes(include = 'object')
df2.head()
# Out:
#   MSZoning LotShape LotConfig LandSlope ExterQual BsmtExposure
# 0       RL      Reg    Inside       Gtl        Gd           No
# 1       RL      Reg       FR2       Gtl        TA           Gd
# 2       RL      IR1    Inside       Gtl        Gd           Mn
# 3       RL      IR1    Corner       Gtl        TA           No
# 4       RL      IR1       FR2       Gtl        Gd           Av

# %%
#23.	Drop column ExterQual
#df.drop(columns =['C', 'D'])
df.drop(['ExterQual'], axis = 1)
# Out:
#     MSSubClass MSZoning  LotArea LotShape LotConfig LandSlope  OverallQual  \
# 0           60       RL     8450      Reg    Inside       Gtl            7
# 1           20       RL     9600      Reg       FR2       Gtl            6
# 2           60       RL    11250      IR1    Inside       Gtl            7
# 3           70       RL     9550      IR1    Corner       Gtl            7
# 4           60       RL    14260      IR1       FR2       Gtl            8
# 5           50       RL    14115      IR1    Inside       Gtl            5
# 6           20       RL    10084      Reg    Inside       Gtl            8
# 7           60       RL    10382      IR1    Corner       Gtl            7
# 8           50       RM     6120      Reg    Inside       Gtl            7
# 9          190       RL     7420      Reg    Corner       Gtl            5
# 10          20       RL    11200      Reg    Inside       Gtl            5
# ...

# %%
#24.	Group data on LotShape and find average LotArea
df.groupby('LotShape')['LotArea'].mean()
# Out:
# LotShape
# IR1    11492.307692
# IR2    12968.000000
# Reg     9085.187500
# Name: LotArea, dtype: float64

# %%
#25.	Write code to get a pivot table as shown (average of MSSubClass)
